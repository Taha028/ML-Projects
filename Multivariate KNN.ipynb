# %%
import pandas as pd
import numpy as np

dc_listings = pd.read_csv("dc_airbnb.csv")
dc_listings.head(3)
# Out:
#   host_response_rate host_acceptance_rate  host_listings_count  accommodates  \
# 0                92%                  91%                   26             4
# 1                90%                 100%                    1             6
# 2                90%                 100%                    2             1
#
#          room_type  bedrooms  bathrooms  beds    price cleaning_fee  \
# 0  Entire home/apt       1.0        1.0   2.0  $160.00      $115.00
# 1  Entire home/apt       3.0        3.0   3.0  $350.00      $100.00
# 2     Private room       1.0        2.0   1.0   $50.00          NaN
#
#   security_deposit  minimum_nights  maximum_nights  number_of_reviews  \
# 0          $100.00               1            1125                  0
# 1              NaN               2              30                 65
# 2              NaN               2            1125                  1
#
#     latitude  longitude         city zipcode state
# ...

# %%
# np.random.seed(1)

# dc_listings = np.random.permutation(dc_listings.index)
# dc_listings

# %%
dc_listings["price"] = dc_listings["price"].str.strip("$").str.replace(",","").astype(float)

# %% [markdown]
# # removing no required columns

# %%
col=["host_response_rate","host_acceptance_rate","room_type","latitude","longitude","zipcode","city","host_listings_count"]

# %%
dc_listings.drop(col, axis=1,inplace=True)

# %%
dc_listings.isnull().sum()
# Out:
# accommodates            0
# bedrooms               21
# bathrooms              27
# beds                   11
# price                   0
# cleaning_fee         1388
# security_deposit     2297
# minimum_nights          0
# maximum_nights          0
# number_of_reviews       0
# state                   0
# dtype: int64

# %%
dc_listings=dc_listings.drop(["cleaning_fee","security_deposit"],axis=1)

# %%
dc_listings.isnull().sum()
# Out:
# accommodates          0
# bedrooms             21
# bathrooms            27
# beds                 11
# price                 0
# minimum_nights        0
# maximum_nights        0
# number_of_reviews     0
# state                 0
# dtype: int64

# %%
dc_listings.dropna(inplace=True)

# %%
dc_listings.isnull().sum()
# Out:
# accommodates         0
# bedrooms             0
# bathrooms            0
# beds                 0
# price                0
# minimum_nights       0
# maximum_nights       0
# number_of_reviews    0
# state                0
# dtype: int64

# %%
dc_listings
# Out:
#       accommodates  bedrooms  bathrooms  beds  price  minimum_nights  \
# 0                4       1.0        1.0   2.0  160.0               1
# 1                6       3.0        3.0   3.0  350.0               2
# 2                1       1.0        2.0   1.0   50.0               2
# 3                2       1.0        1.0   1.0   95.0               1
# 4                4       1.0        1.0   1.0   50.0               7
# ...            ...       ...        ...   ...    ...             ...
# 3718             4       1.0        1.0   2.0  135.0               3
# 3719             2       1.0        2.0   1.0   79.0               3
# 3720             6       2.0        1.0   3.0  275.0               2
# 3721             2       1.0        1.0   1.0  179.0               2
# 3722             3       0.0        1.0   1.0  110.0               2
#
#       maximum_nights  number_of_reviews state
# 0               1125                  0    DC
# ...

# %% [markdown]
# # normalizing

# %%
nomalize_list=(dc_listings-dc_listings.mean()/dc_listings.std())
nomalize_list
# Out:
#       accommodates  bathrooms  bedrooms      beds  maximum_nights  \
# 0         2.405547  -1.143301  -0.43881  0.608938    1.124983e+03
# 1         4.405547   0.856699   1.56119  1.608938    2.998340e+01
# 2        -0.594453  -0.143301  -0.43881 -0.391062    1.124983e+03
# 3         0.405547  -1.143301  -0.43881 -0.391062    1.124983e+03
# 4         2.405547  -1.143301  -0.43881 -0.391062    1.124983e+03
# ...            ...        ...       ...       ...             ...
# 3718      2.405547  -1.143301  -0.43881  0.608938    5.998340e+01
# 3719      0.405547  -0.143301  -0.43881 -0.391062    3.649834e+02
# 3720      4.405547  -1.143301   0.56119  1.608938    2.147484e+09
# 3721      0.405547  -1.143301  -0.43881 -0.391062    2.098340e+01
# 3722      1.405547  -1.143301  -1.43881 -0.391062    1.124983e+03
#
#       minimum_nights  number_of_reviews       price state
# 0           0.382289          -0.516709  158.917895   NaN
# ...
